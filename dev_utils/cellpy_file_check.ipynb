# %%
import os
import time
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cellpy
from cellpy import cellreader

# %matplotlib inline

# %%
from cellpy import log
log.setup_logging(default_level="INFO")
# Out:
# /Users/jepe/scripting/cellpy/cellpy/log.py:38: UserWarning: Could not set custom log-dir - non-existing directory
# None
#   warnings.warn(warning_txt)

# %%
filename = Path("/Users/jepe/Arbeid/Data/celldata/20171120_nb034_11_cc.h5")
print(f"size: {filename.stat().st_size/1_048_576}")

my_data = cellreader.CellpyData()
my_data.load(filename)
dataset = my_data.dataset
# Out:
# size: 17.35070037841797
# (cellpy) - created CellpyData instance
# (cellpy) - loading hdf5
# (cellpy) - /Users/jepe/Arbeid/Data/celldata/20171120_nb034_11_cc.h5
# (cellpy) - -from cellpy-file
# (cellpy) - file loaded

# %%
dataset.step_table.head()
print(dataset.step_table.columns)
# Out:
# Index(['cycle', 'step', 'I_avr', 'I_std', 'I_max', 'I_min', 'I_start', 'I_end',
#        'I_delta', 'I_rate', 'V_avr', 'V_std', 'V_max', 'V_min', 'V_start',
#        'V_end', 'V_delta', 'V_rate', 'Charge_avr', 'Charge_std', 'Charge_max',
#        'Charge_min', 'Charge_start', 'Charge_end', 'Charge_delta',
#        'Charge_rate', 'Discharge_avr', 'Discharge_std', 'Discharge_max',
#        'Discharge_min', 'Discharge_start', 'Discharge_end', 'Discharge_delta',
#        'Discharge_rate', 'IR', 'IR_pct_change', 'type', 'info'],
#       dtype='object')

# %% [markdown]
# tot usage for `make_step_table``:
# - 7.951 sec
# - uses 5.15 sec in `_extract_step_values`

# %%
old_step_table = my_data.dataset.step_table.copy()

# %%
my_data.make_step_table_new()
# Out:
# (cellpy) - masking and labelling steps
# (cellpy) - checking discharge - discharge changed
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 924    False
# 925    False
# 926     True
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932     True
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938     True
# 939    False
# 940    False
# 941    False
# 942    False
# 943     True
# 944    False
# 945    False
# 946    False
# 947    False
# 948     True
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# Name: (discharge, delta), Length: 954, dtype: bool
# (cellpy) - checking discharge - current negative
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7       True
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16      True
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 924    False
# 925    False
# 926     True
# 927     True
# 928    False
# 929    False
# 930    False
# 931    False
# 932     True
# 933     True
# 934    False
# 935    False
# 936    False
# 937    False
# 938     True
# 939     True
# 940    False
# 941    False
# 942    False
# 943     True
# 944     True
# 945    False
# 946    False
# 947    False
# 948     True
# 949     True
# 950    False
# 951    False
# 952    False
# 953    False
# Name: (current, avr), Length: 954, dtype: bool
# (cellpy) - checking charge
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 924    False
# 925    False
# 926    False
# 927    False
# 928    False
# 929     True
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935     True
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941     True
# 942    False
# 943    False
# 944    False
# 945    False
# 946     True
# 947    False
# 948    False
# 949    False
# 950    False
# 951     True
# 952    False
# 953    False
# Length: 954, dtype: bool
# 0      ocvrlx_down
# 1               ir
# 2        discharge
# 3               ir
# 4        ocvrlx_up
# 5           charge
# 6      ocvrlx_down
# 7        discharge
# 8               ir
# 9        ocvrlx_up
# 10          charge
# 11              ir
# 12     ocvrlx_down
# 13       discharge
# 14       ocvrlx_up
# 15          charge
# 16              ir
# 17     ocvrlx_down
# 18       discharge
# 19              ir
# 20       ocvrlx_up
# 21          charge
# 22              ir
# 23     ocvrlx_down
# 24       discharge
# 25              ir
# 26       ocvrlx_up
# 27          charge
# 28              ir
# 29     ocvrlx_down
#           ...
# 924             ir
# 925    ocvrlx_down
# 926      discharge
# 927             ir
# 928      ocvrlx_up
# 929         charge
# 930             ir
# 931    ocvrlx_down
# 932      discharge
# 933             ir
# 934      ocvrlx_up
# 935         charge
# 936             ir
# 937    ocvrlx_down
# 938      discharge
# 939             ir
# 940      ocvrlx_up
# 941         charge
# 942    ocvrlx_down
# 943      discharge
# 944             ir
# 945      ocvrlx_up
# 946         charge
# 947    ocvrlx_down
# 948      discharge
# 949             ir
# 950      ocvrlx_up
# 951         charge
# 952             ir
# 953    ocvrlx_down
# Name: type, Length: 954, dtype: object
# /Users/jepe/scripting/cellpy/cellpy/readers/cellreader.py:1378: RuntimeWarning: invalid value encountered in double_scalars
#   difference = (last(x) - first(x)) * 100 / first(x)

# %%
new_step_table = my_data.dataset.step_table.copy()

# %%
mask_current_negative = new_step_table.loc[:, "current_avr"] < - 0.0000000000001
mask_discharge_changed = new_step_table.loc[:, "discharge_delta"].abs() > 2.0
mask_current_negative & mask_discharge_changed
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13      True
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 924    False
# 925    False
# 926     True
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932     True
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938     True
# 939    False
# 940    False
# 941    False
# 942    False
# 943     True
# 944    False
# 945    False
# 946    False
# 947    False
# 948     True
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# Length: 954, dtype: bool

# %%
old_step_table[["I_avr", "Charge_delta", "Discharge_delta", "type"]].head(20)
# Out:
#           I_avr Charge_delta Discharge_delta         type
# 0             0            0               0  ocvrlx_down
# 1   4.52922e-07            0               0           ir
# 2  -0.000267023            0      6.2199e+12    discharge
# 3  -1.66254e-06            0               0           ir
# 4             0            0               0    ocvrlx_up
# 5   0.000266865  3.70136e+08               0       charge
# 6             0            0               0  ocvrlx_down
# 7  -0.000267042            0     1.02124e+08    discharge
# 8  -2.01512e-06            0               0           ir
# 9             0            0               0    ocvrlx_up
# 10  0.000266919  2.00673e+08               0       charge
# 11  4.52922e-07            0               0           ir
# 12            0            0               0  ocvrlx_down
# 13 -0.000267037            0     2.12177e+08    discharge
# 14            0            0               0    ocvrlx_up
# 15  0.000266925  2.27035e+12               0       charge
# 16 -2.01512e-06            0               0           ir
# 17            0            0               0  ocvrlx_down
# 18 -0.000534114            0     1.24208e+12    discharge
# 19 -0.000534054            0               0           ir

# %%
new_step_table[["current_avr", "charge_delta",  "discharge_delta", "type"]].head(20)
# Out:
#      current_avr  charge_delta  discharge_delta         type
# 0   0.000000e+00  0.000000e+00     0.000000e+00  ocvrlx_down
# 1   4.529220e-07  0.000000e+00     0.000000e+00           ir
# 2  -2.670227e-04  0.000000e+00     6.219901e+12    discharge
# 3  -1.662540e-06  0.000000e+00     0.000000e+00           ir
# 4   0.000000e+00  0.000000e+00     0.000000e+00    ocvrlx_up
# 5   2.668649e-04  3.701365e+08     0.000000e+00       charge
# 6   0.000000e+00  0.000000e+00     0.000000e+00  ocvrlx_down
# 7  -2.670422e-04  0.000000e+00     1.021244e+08    discharge
# 8  -2.015117e-06  0.000000e+00     0.000000e+00           ir
# 9   0.000000e+00  0.000000e+00     0.000000e+00    ocvrlx_up
# 10  2.669187e-04  2.006727e+08     0.000000e+00       charge
# 11  4.529220e-07  0.000000e+00     0.000000e+00           ir
# 12  0.000000e+00  0.000000e+00     0.000000e+00  ocvrlx_down
# 13 -2.670374e-04  0.000000e+00     2.121771e+08    discharge
# 14  0.000000e+00  0.000000e+00     0.000000e+00    ocvrlx_up
# 15  2.669245e-04  2.270347e+12     0.000000e+00       charge
# 16 -2.015117e-06  0.000000e+00     0.000000e+00           ir
# 17  0.000000e+00  0.000000e+00     0.000000e+00  ocvrlx_down
# 18 -5.341140e-04  0.000000e+00     1.242082e+12    discharge
# 19 -5.340537e-04  0.000000e+00     0.000000e+00           ir

# %%
new_step_table.type.unique()
# Out:
# array(['ocvrlx_down', 'ir', 'discharge', 'ocvrlx_up', 'charge'],
#       dtype=object)

# %%
old_step_table.type.unique()
# Out:
# array(['ocvrlx_down', 'ir', 'discharge', 'ocvrlx_up', 'charge'],
#       dtype=object)

# %% [markdown]
# ```python
# raw_limits["current_hard"] = 0.0000000000001
# raw_limits["current_soft"] = 0.00001
# raw_limits["stable_current_hard"] = 2.0
# raw_limits["stable_current_soft"] = 4.0
# raw_limits["stable_voltage_hard"] = 2.0
# raw_limits["stable_voltage_soft"] = 4.0
# raw_limits["stable_charge_hard"] = 2.0
# raw_limits["stable_charge_soft"] = 5.0
# raw_limits["ir_change"] = 0.00001
#
#
# current_limit_value_hard = self.raw_limits["current_hard"]
# current_limit_value_soft = self.raw_limits["current_soft"]
# stable_current_limit_hard = self.raw_limits["stable_current_hard"]
# stable_current_limit_soft = self.raw_limits["stable_current_soft"]
# stable_voltage_limit_hard = self.raw_limits["stable_voltage_hard"]
# stable_voltage_limit_soft = self.raw_limits["stable_voltage_soft"]
# stable_charge_limit_hard = self.raw_limits["stable_charge_hard"]
# stable_charge_limit_soft = self.raw_limits["stable_charge_soft"]
# ir_change_limit = self.raw_limits["ir_change"]
#
#
#
# ```

# %%
#df_steps.loc[mask_discharge_changed & mask_current_negative, shdr.type] = 'discharge'
#mask_discharge_changed = df_steps.loc[:, (shdr.charge, "delta")].abs() > stable_charge_limit_hard
#mask_current_negative = df_steps.loc[:, (shdr.current, "avr")] < - current_limit_value_hard
n3 = new_step_table.iloc[2,:]
o3 = old_step_table.iloc[2,:]

# %%
t1 = "current_avr"
t2 = "I_avr"

print(n3[t1] == o3[t2])
print(f"old value (for steptable[{t2}]): {o3[t2]}")
print(f"new value (for steptable[{t1}]): {n3[t1]}")

print(o3[t2] < - 0.0000000000001)
print(n3[t1] < - 0.0000000000001)
# Out:
# True
# old value (for steptable[I_avr]): -0.00026702274811030613
# new value (for steptable[current_avr]): -0.00026702274811030613
# True
# True

# %%
t1 = "discharge_delta"
t2 = "Discharge_delta"

print(n3[t1] == o3[t2])
print(f"old value (for steptable[{t2}]): {o3[t2]}")
print(f"new value (for steptable[{t1}]): {n3[t1]}")

print(o3[t2] > 2.0)
print(n3[t1] > 2.0)
# Out:
# True
# old value (for steptable[Discharge_delta]): 6219901174956.411
# new value (for steptable[discharge_delta]): 6219901174956.411
# True
# True
